# %% [markdown]
# <a href="https://colab.research.google.com/github/MuhsinaPP/MachineLearning/blob/master/global_population_growth_2024.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **DATASET INFORMATION**
#
# This dataset provides simulated global population growth rates for various cities in 2024. It includes data on city names, countries, population figures for 2023, annual growth rates, and projected populations for 2024.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
df=pd.read_csv("/content/drive/MyDrive/Dataset/global_population_growth_2024.csv")
df
# Out:
#             City    Country  Population_2023  Growth_Rate (%)  Population_2024
# 0    Los Angeles        USA         26836512         1.308574         27187687
# 1       Shanghai      China         11673774         1.568945         11856929
# 2          Cairo      Egypt         22201723         4.871278         23283230
# 3         Mumbai      India         11440139         1.314396         11590507
# 4    Los Angeles        USA          3792427         4.344733          3957197
# ..           ...        ...              ...              ...              ...
# 995       Sydney  Australia         29207970         2.687002         29992788
# 996       Sydney  Australia         12006745         3.097399         12378641
# 997        Cairo      Egypt         21991495         0.696826         22144737
# 998        Tokyo      Japan         12950831         1.053515         13087269
# 999       Moscow     Russia          2257949         3.013891          2326001
#
# [1000 rows x 5 columns]

# %%
df.columns
# Out:
# Index(['City', 'Country', 'Population_2023', 'Growth_Rate (%)',
#        'Population_2024'],
#       dtype='object')

# %%
df.isna().sum()
# Out:
# City               0
# Country            0
# Population_2023    0
# Growth_Rate (%)    0
# Population_2024    0
# dtype: int64

# %%
df.head(10)
# Out:
#           City    Country  Population_2023  Growth_Rate (%)  Population_2024
# 0  Los Angeles        USA         26836512         1.308574         27187687
# 1     Shanghai      China         11673774         1.568945         11856929
# 2        Cairo      Egypt         22201723         4.871278         23283230
# 3       Mumbai      India         11440139         1.314396         11590507
# 4  Los Angeles        USA          3792427         4.344733          3957197
# 5       Sydney  Australia         12309411         2.715250         12643642
# 6       London         UK         21134895         1.612540         21475703
# 7  Los Angeles        USA          6748035         4.418375          7046188
# 8        Cairo      Egypt          5390020         2.503874          5524979
# 9       Mumbai      India          3681719         2.816678          3785421

# %%
df.tail(10)
# Out:
#             City    Country  Population_2023  Growth_Rate (%)  Population_2024
# 990        Cairo      Egypt         21939281         2.902854         22576146
# 991    Sao Paulo     Brazil         29175911         1.139617         29508404
# 992    Sao Paulo     Brazil          1260116         0.552680          1267080
# 993        Cairo      Egypt         29134286         2.399154         29833262
# 994  Los Angeles        USA          7086368         1.827683          7215884
# 995       Sydney  Australia         29207970         2.687002         29992788
# 996       Sydney  Australia         12006745         3.097399         12378641
# 997        Cairo      Egypt         21991495         0.696826         22144737
# 998        Tokyo      Japan         12950831         1.053515         13087269
# 999       Moscow     Russia          2257949         3.013891          2326001

# %%
df.shape
# Out:
# (1000, 5)

# %%
df.dtypes
# Out:
# City                object
# Country             object
# Population_2023      int64
# Growth_Rate (%)    float64
# Population_2024      int64
# dtype: object

# %%
df.count()
# Out:
# City               1000
# Country            1000
# Population_2023    1000
# Growth_Rate (%)    1000
# Population_2024    1000
# dtype: int64

# %%
df['Growth_Rate (%)'].hist()
# Out:
# <Axes: >

# %%
sns.histplot(x=df["Growth_Rate (%)"],kde=True)
# Out:
# <Axes: xlabel='Growth_Rate (%)', ylabel='Count'>

# %% [markdown]
# The histogram shows the distribution of the growth rate. The histogram has a peak around 3% growth rate. This indicates that the majority of the data points had a growth rate close to 3%. The distribution appears to be slightly skewed to the right. This means that there are more data points with higher growth rates than lower growth rates.
# In conclusion, this histogram suggests that the growth rates are primarily clustered around 3% with a slight tendency towards higher growth rates.

# %%
df["Population_2023"].hist()
# Out:
# <Axes: >

# %%
df["Population_2024"].hist()
# Out:
# <Axes: >

# %%
top_10_cities_2023 = df.nlargest(10, 'Population_2023')
plt.figure(figsize=(12, 8))
sns.barplot(x=df['Population_2023'], y=df['City'], data=top_10_cities_2023)
plt.title('Top 10 Cities by Population in 2023')
plt.xlabel('Population in 2023')
plt.ylabel('City')
plt.show()

# %%
# Top 10 Cities by Population Growth Rate
top_10_growth_rate = df.nlargest(10, 'Growth_Rate (%)')
plt.figure(figsize=(12, 8))
sns.barplot(x=df['Growth_Rate (%)'], y=df['City'], data=top_10_growth_rate)
plt.title('Top 10 Cities by Population Growth Rate')
plt.xlabel('Growth Rate (%)')
plt.ylabel('City')
plt.show()

# %%
# Correlation Heatmap
numeric_df = df.select_dtypes(include=[np.number])
plt.figure(figsize=(10, 6))
sns.heatmap(numeric_df.corr(), annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Correlation Heatmap')
plt.show()

# %%
df.describe()
# Out:
#        Population_2023  Growth_Rate (%)  Population_2024
# count     1.000000e+03      1000.000000     1.000000e+03
# mean      1.555745e+07         2.738825     1.598217e+07
# std       8.188922e+06         1.296754     8.415373e+06
# min       1.076218e+06         0.507043     1.082482e+06
# 25%       8.767388e+06         1.606459     8.914246e+06
# 50%       1.538409e+07         2.782955     1.589204e+07
# 75%       2.265558e+07         3.819846     2.322489e+07
# max       2.999429e+07         4.997362     3.122415e+07

# %%
#Removing the duplicates(if any)

df1=df.drop_duplicates()
df1
# Out:
#             City    Country  Population_2023  Growth_Rate (%)  Population_2024
# 0    Los Angeles        USA         26836512         1.308574         27187687
# 1       Shanghai      China         11673774         1.568945         11856929
# 2          Cairo      Egypt         22201723         4.871278         23283230
# 3         Mumbai      India         11440139         1.314396         11590507
# 4    Los Angeles        USA          3792427         4.344733          3957197
# ..           ...        ...              ...              ...              ...
# 995       Sydney  Australia         29207970         2.687002         29992788
# 996       Sydney  Australia         12006745         3.097399         12378641
# 997        Cairo      Egypt         21991495         0.696826         22144737
# 998        Tokyo      Japan         12950831         1.053515         13087269
# 999       Moscow     Russia          2257949         3.013891          2326001
#
# [1000 rows x 5 columns]

# %%
#Percentage of missing values per column

df1.isna().sum()/df1.shape[0]
# Out:
# City               0.0
# Country            0.0
# Population_2023    0.0
# Growth_Rate (%)    0.0
# Population_2024    0.0
# dtype: float64

# %%
df1=df1.dropna()
len(df1)
# Out:
# 1000

# %%
# Prepare the data for modeling
x = df[['Population_2023', 'Growth_Rate (%)']]
y = df['Population_2024']

# %%
sns.regplot(x=df1["Population_2024"],y=y)
# Out:
# <Axes: xlabel='Population_2024', ylabel='Population_2024'>

# %%
sns.regplot(x=df1["Growth_Rate (%)"],y=y)
# Out:
# <Axes: xlabel='Growth_Rate (%)', ylabel='Population_2024'>

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.20,random_state=42) #result reproducable
x_train
# Out:
#      Population_2023  Growth_Rate (%)
# 29           7262105         1.619214
# 535         12318792         0.658901
# 695         17011737         2.566579
# 557          4229028         0.918458
# 836         23750760         3.829569
# ..               ...              ...
# 106         14781009         1.971649
# 270          2500844         4.966176
# 860         28050901         1.837570
# 435         28866537         1.834410
# 102         15246173         3.051573
#
# [800 rows x 2 columns]

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(x_test)

# %%
from sklearn.metrics import mean_absolute_error
meanR=mean_absolute_error(y_test,y_pred)
meanR
# Out:
# 80380.72205105779

# %%
from sklearn.metrics import mean_absolute_percentage_error
perR=mean_absolute_percentage_error(y_test,y_pred)
perR
# Out:
# 0.010914156992984293

# %%
from sklearn.metrics import mean_squared_error
sqrR=mean_squared_error(y_test,y_pred)
sqrR
# Out:
# 11444998310.491167

# %%
from sklearn.metrics import r2_score
r2R=r2_score(y_test,y_pred)
r2R
# Out:
# 0.9998398173222396

# %% [markdown]
# **Conclusion**
#
# In this, we explored the global population growth dataset, performed exploratory data analysis, and built a predictive model to forecast population growth.
